# %%
## Assignment Part-1
# Question 

# 1] Why do we call Python as a general purpose and high-level programming language?

# Answer :
        
        '''Python is called a general purpose and high-level programming language because it
        can be used for developing a wide range of applications for a wide variety of platforms.'''
        
# 2] Why is Python called a dynamically typed language?

# Answer :
        
        '''Python is both a strongly typed and a dynamically typed language. Strong typing means that
        variables do have a type and that the type matters when performing operations on a variable. 
        Dynamic typing means that the type of the variable is determined only during runtime.'''

# 3] List some pros and cons of Python programming language?

# Answer :
        
         '''Pros: 
                 - Python is a very versatile language that can be used for a wide variety of tasks, from web development
                   to data science.
                 - Python is relatively easy to learn, even for beginners.
                 - Python has a large and supportive community.
                 - Python is an open source language, which means that it is free to use and distribute.
                 - Python runs on many different platforms.
                 - Python comes with a large standard library that includes many modules and functions for a wide variety
                   of tasks.
                 - Python is an interpreted language, which means that code can be executed as soon as it is written,
                   without the need for a compiler.
            Cons: 
                 - Python can be slower than some other programming languages.
                 - Python is not well suited for mobile development.   
                 - Python's dynamic typing can lead to some unexpected behavior, which can be confusing for beginners.     
                 - Python does not scale well. It is not suitable for large projects with millions of lines of code.
         '''
        
# 4]  In what all domains can we use Python?

# Answer :
         '''Python can be used in many domains, including web development, scientific computing,
            data science, artificial intelligence, and more.'''
    
# 5]  What are variable and how can we declare them?

# Answer :
          '''In Python, variables are created when you assign a value to them.

            To create a variable, you just assign it a value and then start using it. There is no specific syntax for 
            declaring variables in Python.

            You can create a variable by simply assigning it a value, as follows:

            x = 10

            y = "Hello"

            z = True

            You can also declare multiple variables in a single line, as follows:

            x, y, z = 10, "Hello", True'''
    
    
# 6]  How can we take an input from the user in Python?

# Answer :
         '''There are various ways to take input from the user in Python. 
            
            Some of the most common ways are through the 
            input() function,
            raw_input() function, 
            and through command line arguments.'''
    
# 7]  What is the default datatype of the value that has been taken as an input using input() function?

# Answer :
         '''The default datatype of the value taken as input using the input() function is a string.

            Example:

            x = input("Enter a value: ")

            print(type(x))

            Output:

            Enter a value: 10

            <class 'str'>   '''
    
# 8]  What is type casting?

# Answer :
          '''Type casting is a method of changing an object from one data type to another.
          
          In Python, type casting can be done using the built-in functions int(), float(), and str().
          
          For example, you may have a list of integers that you want to convert to a list of strings. Type casting can be done with the built-in function, str():

          my_list = [1, 2, 3]

          my_list_as_strings = [str(i) for i in my_list]

          my_list_as_strings

          ['1', '2', '3']



          You can also use the built-in function, int(), to convert strings to integers:

          my_string = '123'

          my_string_as_int = int(my_string)
       
          my_string_as_int

          123
          '''
    
# 9]  Can we take more than one input from the user using single input() function? If yes, how? If no, why?

# Answer :
         '''No, we cannot take more than one input from the user using a single input() function. 
           
            This is because the input() function can only take in a single string value from the user.
            
            If we try to take in multiple values from the user, it will cause an error.'''
    
# 10]  What are keywords?

# Answer :
         '''In the context of programming, keywords are words that have a specific meaning in the language. 
         
            In Python, keywords are case sensitive and they cannot be used as variable names,
            
            function names, or any other identifiers.'''
    
# 11]  Can we use keywords as a variable? Support your answer with reason.

# Answer :
         '''No, we cannot use keywords as variables in Python. This is because keywords are reserved words that
         
            have special meaning in Python and cannot be used as identifiers for variables, functions, classes, etc.'''
    
    
# 12]  What is indentation? What's the use of indentaion in Python?

# Answer : 
          '''Indentation is used in Python to indicate a block of code. Python relies on indentation, using whitespace, 
          
             to define scope in the code. Other programming languages often use curly-brackets for this purpose.

             Indentation is important in Python. All the code within a certain code block must be indented the same amount. 
             
             The amount of indentation is up to the programmer, but it must be consistent throughout that block.'''
    
    
# 13]  How can we throw some output in Python?

# Answer :
          '''There are many ways to throw some output in Python. 
          
             Some common ways are to use the print statement, or the write() 
              
             or writelines() methods of the file object.'''
    
# 14]  How can we throw some output in Python?

# Answer :
          '''Operators are special symbols in Python that carry out operations on variables and values.
 
          
             The values the operator is applied to are called operands.
             
             Python divides the operators in the following groups:

             Arithmetic operators
             
             Assignment operators
             
             Comparison operators
             
             Logical operators
             
             Identity operators
             
             Membership operators
             
             Bitwise operators'''
    
    
# 15]  What is difference between / and // operators?

# Answer :
         '''The / operator is the division operator. The // operator is the floor division operator.
         
            The / operator divides the two operands and returns the quotient.

            The // operator divides the two operands and returns the quotient, discarding the remainder.'''
    
# 16]  Write a code that gives following as an output.

#      iNeuroniNeuroniNeuroniNeuron

# Answer :
          '''print("iNeuroniNeuroniNeuroniNeuron")
             or
             print("iNeuron"*4)
          
          '''
    
# 17]  Write a code to take a number as an input from the user and check if the number is odd or even.

# Answer :
          '''
          
          number=int(input("Enter the input in digit"))
               
             if (number % 2) == 0:
                 print(f"{number} is Even number ")
             else:
                 print(f"{number} is Odd number ")


        '''
    
# 18]  What are boolean operator?

# Answer :
          '''Boolean operators are the operators that work on Boolean values and return a Boolean result.
          
             The Boolean operators in Python are and, or, not.'''
    
# 19]  What will the output of the following?

#              1 or 0

#              0 and 0

#              True and False and True

#              1 or 0 or 0

# Answer :
          '''output :
                     1 or 0 is 1
                     
                     0 and 0 is 0
                     
                     True and False and True is False
                     
                     1 or 0 or 0 is 1

          
          '''
    
# 20]  What are conditional statements in Python?

# Answer :
          '''A conditional statement is a statement that checks if a certain condition is 
             
             true before executing the code.

             If the condition is true, the code will be executed. If the condition is false, 
             
             the code will not be executed.

             Here is an example of a conditional statement:

             if (x > 10):
                  print("x is greater than 10")'''
    
# 21]  What is use of 'if', 'elif' and 'else' keywords?

# Answer :
          '''The 'if' keyword is used to check for a certain condition. If the condition is true, 
             
             the code block following
          
             the 'if' keyword will be executed. The 'elif' keyword is used to check for another 
             
             condition if the first condition is false.
          
             The 'else' keyword is used to execute a code block if all the other conditions are false.'''
    
# 22]  Write a code to take the age of person as an input and if age >= 18 display "I can vote". 
#      If age is < 18 display "I can't vote".

# Answer :
          '''age=int(input("Enter the age "))
             if age >= 18:
                 print("I can vote")
             else:
                 print("i can't vote")'''
    
# 23]  Write a code that displays the sum of all the even numbers from the given list.

#      numbers = [12, 75, 150, 180, 145, 525, 50]

# Answer :
          '''numbers = [12, 75, 150, 180, 145, 525, 50]
          
             sum=0
             for i in numbers:
                  if i % 2 == 0:
                          sum += i
             print(sum)

        '''
    
# 24]  Write a code to take 3 numbers as an input from the user and display the greatest no as output.

# Answer :
          '''
            a = int(input("Enter first number: "))
            b = int(input("Enter second number: "))
            c = int(input("Enter third number: "))
 
            if (a > b) and (a > c):
               largest = a
            elif (b > a) and (b > c):
               largest = b
            else:
               largest = c
 
            print("The largest number is",largest)'''
    
# 25]  Write a program to display only those numbers from a list that satisfy the following conditions

#       The number must be divisible by five

#       If the number is greater than 150, then skip it and move to the next number

#       If the number is greater than 500, then stop the loop

#       numbers = [12, 75, 150, 180, 145, 525, 50]

# Answer :
          '''numbers = [12, 75, 150, 180, 145, 525, 50]
            for i in numbers:
                if i % 5 == 0:
                    if i >150:
                        if i > 500:
                            break
                
                
            print(i)
           '''
